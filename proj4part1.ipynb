# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_rec_new=pd.read_csv("/Users/Jyo/Documents/GA/latest.csv")

# %%
df_rec_new=df_rec_new[df_rec_new["skills3"].str.lstrip()!=""]
#df_rec_lat.loc[1299,"skills3"]

# %%
df_rec_new.drop(["Unnamed: 0","Unnamed: 0.1","Unnamed: 0.1.1"],axis=1,inplace=True)

# %%
df_rec_new.shape
# Out:
# (1135, 14)

# %%
df_rec_new.drop([880,1078,1229,1404,1418,1213,880,141,797,1055,1439,1422,793,852,1262,809,1440,1138],axis=0,inplace=True)

# %%
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Teaching - Tertiary"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Research & Fellowships"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Marketing Communications"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Agronomy & Farm Services"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Aged & Disability Support"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Strategy & Planning"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Mining - Engineering & Maintenance"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Account & Relationship Management"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Administrative Assistants"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Audit - External"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Biotechnology & Genetics"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Compliance & Risk"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Civil/Structural Engineering"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Client & Sales Administration"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Clinical/Medical Research"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Consulting & Generalist HR"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Data Entry & Word Processing"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Electrical/Electronic Engineering"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Field Engineering"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Food Technology & Safety"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Insolvency & Corporate Recovery"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Litigation & Dispute Resolution"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Management & Support"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Mechanical Engineering"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Mining - Engineering & Maintenance"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Mining - Processing"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Payroll"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Policy"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Project Engineering"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Production, Planning & Scheduling"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Purchasing, Procurement & Inventory"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Recruitment - Agency"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Road Transport"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Sales - Pre & Post"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Sales Representatives/Consultants"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Sales Coordinators"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Security"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Strategy & Planning"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Technicians"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Telecommunications"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Testing & Quality Assurance"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Training & Development"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Training & Development"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Water & Waste Engineering"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Web & Interaction Design"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Web Development & Production"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Direct Marketing & CRM"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Digital & Search Marketing"]
df_rec_new=df_rec_new[df_rec_new['class2'].str.strip()!="Recruitment - Internal"]

# %%
word=["JAVA",
"DEVOPS",
"REACT.JS",
"NODE.JS",
"JAVASCRIPT",
"FULL STACK",
"WEB",
"OSI",
"SOA",
"MANAGER",
"LECTURER",
"SUPPORT",
"MAINTENANCE",
"TECHNICAL",
"(M24)",    
"PHD",
"CX",
"M37",
"(M37)",
"MAINFRAME",
"PROFESSOR",
"DIRECTOR",
"DEVELOPER",
"PARTNER",
"TELCO",
"IGLOO",
"ADMINISTRATOR",
"MIFIDII",
"(CRM)",
"PRODUCTS",
"MANAGEMENT","SAP","M24","PRODUCT","BI","LECTURERS","WAREHOUSE","GRADUATE"]
word_s=set(word)

# %%
for index,name in df_rec_new["title"].iteritems():
    name_s=set(name.upper().split())
    #print(index,word_s)
    #print(index,name_s)
    if name_s.intersection(word_s):
        print(index,name_s)
        if index !=1321 and index !=937 and index != 17:
            df_rec_new.drop(index,inplace=True)
# Out:
# 7 {'DATA', '-', 'ANALYST', 'WEB', 'BIG', 'SENIOR', 'ANALYTICS'}
# 12 {'DATA', '|', 'SCIENTIST', 'DEVELOPER'}
# 17 {'/', 'DATA', 'TO', '$1,200PD', 'CONTRACT', 'CONSULTANT', 'SCIENTIST', 'SENIOR', 'PRODUCTS', '::', 'UP'}
# 37 {'MANAGER', 'DATA', 'CIRCA', '+', 'SCIENCE', '-', '$200K', 'SENIOR', 'BONUS', '::'}
# 76 {'PYTHON', 'DEVELOPER'}
# 108 {'DATA', 'ANALYST', 'WAREHOUSE'}
# 109 {'/', 'LEAD', 'CONSULTANT', 'SENIOR', 'TECHNICAL'}
# 132 {'MANAGER', '/', 'DATA', 'MARKETING', 'MEDIA', 'SCIENTIST', 'DIGITAL', 'ANALYTICS'}
# 143 {'ETL', '-', 'DEVELOPER', 'CONTRACT', 'SENIOR', '$900PD'}
# 157 {'/', 'DATA', 'DEVELOPER', 'HADOOP', 'ENGINEER'}
# 163 {'PROGRAM', 'SCIENCE/DATA', 'COMPUTER', 'ANALYTICS', 'GRADUATE', 'SCIENCE-MATHEMATICS/DATA', '2020'}
# 164 {'PROGRAM', 'SCIENCE/DATA', 'COMPUTER', 'ANALYTICS', 'GRADUATE', 'SCIENCE-MATHEMATICS/DATA', '2020'}
# 170 {'/', 'DATA', 'DEVELOPER', 'BI', 'CONSULTANT', 'ANALYTICS'}
# 175 {'DATA', 'BI', 'ANALYST', 'POWER'}
# ...

# %%
 df_rec_new.shape
# Out:
# (735, 14)

# %%
df_rec_new["newclass1"]=""
for index,name in df_rec_new["class1"].iteritems():
    print(index,name)
    name=name.strip()
    df_rec_new.loc[index,"newclass1"]="Others"
    if name in ['Information & Communication Technology','Science & Technology']:
    
        df_rec_new.loc[index,"newclass1"]="Information Technolog"
        
    if name in ['Government & Defence','Education & Training']:
        df_rec_new.loc[index,"newclass1"]="Govt & Def & Edu & Train"
        
    if name in ['Consulting & Strategy','Engineering']:
        df_rec_new.loc[index,"newclass1"]='Consulting & Strategy & Eng'
        
    if name in ['Manufacturing','Transport & Logistics','Construction']:
        df_rec_new.loc[index,"newclass1"]='Man & Trans & Logistics & Cons'
        
    if name in ['Healthcare & Medical']:
        df_rec_new.loc[index,"newclass1"]='Healthcare & Medical'
       
    if name in ['Advertising','Advertising, Arts & Media','Arts & Media','Marketing & Communications','Sales']:
        df_rec_new.loc[index,"newclass1"]='Adv & Arts & Media & Mark & Comm & Sales'
       
    if name in ['Human Resources & Recruitment','Administration & Office Support']:
        df_rec_new.loc[index,"newclass1"]='Human Resources & Recruitment & Admin & Office Support'
        
    if name in ['Banking & Financial Services','Insurance & Superannuation','Accounting']:
        df_rec_new.loc[index,"newclass1"]='Financial Services'
# Out:
# 0 Information & Communication Technology
# 1 Information & Communication Technology
# 2 Information & Communication Technology
# 3 Information & Communication Technology
# 4 Information & Communication Technology
# 5 Information & Communication Technology
# 6 Information & Communication Technology
# 8 Information & Communication Technology
# 9 Information & Communication Technology
# 10 Consulting & Strategy
# 11 Engineering
# 13 Information & Communication Technology
# 14 Information & Communication Technology
# 15 Science & Technology
# 16 Government & Defence
# 17 Information & Communication Technology
# 18 Information & Communication Technology
# 19 Information & Communication Technology
# 20 Education & Training
# 21 Information & Communication Technology
# 22 Information & Communication Technology
# 23 Information & Communication Technology
# 24 Information & Communication Technology
# 25 Science & Technology
# 26 Science & Technology
# ...

# %%
df_new=pd.DataFrame()
df_new["label"]=pd.cut(df_rec_new.loc[df_rec_new["new"] >0,"new"], 4,labels=False)

# %%
df_rec_new=df_rec_new.merge(df_new,how='left',left_index=True, right_index=True)

# %%
df_rec_new.groupby('label')['new'].min()
# Out:
# label
# 0.0     11099.0
# 1.0    188422.5
# 2.0    378300.0
# 3.0    574500.0
# Name: new, dtype: float64

# %%
df_rec_new.groupby('label')['new'].max()
# Out:
# label
# 0.0    185367.0
# 1.0    349200.0
# 2.0    436500.0
# 3.0    710000.0
# Name: new, dtype: float64

# %%
df_rec_new["skills"]=""
for index,name in df_rec_new["skills3"].iteritems():
    
    name=name.strip()
    if name in ['ANALYST','JUNIOR ANALYST ENGINEER','JUNIOR ENGINEER','ANALYST    ORACLE','ANALYST  MODELLING','ANALYTICS  AI','AI','ANALYST  PREDICTIVE','ANALYTICS','JUNIOR ANALYST','ANALYST ANALYTICS','ANALYST  SQL','RESEARCH   ANALYST','LEARNING','ENGINEER  LEARNING']:
        df_rec_new.loc[index,"skills"]=" Jr Analysts"
        
            
    if name in ['SCIENTIST SENIOR','SENIOR   CONSULTANT','SPECIALIST   ENGINEER    IOT','CONSULTANT','SENIOR   CONSULTANT  SQL  POWERBI','SCIENTIST    ENGINEER','SPECIALIST     MODELLING','CONSULTANT  INTELLIGENCE','ENGINEER  MACHINE AI LEARNING','SENIOR   ANALYST  INTELLIGENCE','MACHINE LEARNING','SCIENTIST    ANALYTICS GOOGLE R PYTHON','SCIENTIST      MACHINE PYTHON LEARNING  C++','SCIENTIST   JUNIOR','SCIENTIST      AI LEARNING','SCIENTIST     AZURE','SCIENTIST    ENGINEER  MACHINE LEARNING','SCIENTIST    ANALYTICS  AI','SCIENTIST','SCIENTIST    ANALYTICS','SPECIALIST   ANALYTICS','SCIENTIST    ANALYST','SCIENTIST     BIGAZURE','LEAD','ANALYST  INTELLIGENCE']:
        df_rec_new.loc[index,"skills"]='Sr Scientist'
        
    if name in ['SENIOR   ANALYST','EXPERT   ANALYST  VISUALISATION','SENIOR   ANALYST ANALYTICS','ANALYTICS ENGINEER  MACHINE','ENGINEER  MACHINE LEARNING','SENIOR LEAD  ENGINEER','LEAD  ANALYST ANALYTICS','LEADER','SENIOR   CONSULTANT  INTELLIGENCE','HEAD','CONSULTANT  TABLEAU','LEADER','LEAD  CONSULTANT','CONSULTANT ENGINEER','SENIOR LEAD','LEAD  ANALYTICS','SENIOR   ANALYTICS','LEAD  ANALYST','SENIOR   CONSULTANT ANALYTICS','LEAD  ANALYTICS  INTELLIGENCE','INTELLIGENCE','CONSULTANT ANALYTICS','STATISTICS','SENIOR']:
        df_rec_new.loc[index,"skills"]='Sr. Analyst'
        
    if name in ['ANALYTICS ENGINEER','SCIENTIST   JUNIOR','ANALYTICS  INTELLIGENCE','SCIENTIST    CONSULTANT','LEAD    INTELLIGENCE','SENIOR     INTELLIGENCE','SCIENTIST  LEAD    MACHINE PYTHON LEARNING','HEAD  ANALYTICS','SPECIALIST','SCIENTIST  LEAD','SCIENTIST SENIOR   ANALYTICS','SCIENTIST RESEARCH SENIOR     MODELLING','SENIOR','INTELLIGENCE','SPECIALIST SENIOR','SCIENTIST SENIOR   CONSULTANT','ENGINEER  MACHINE AI LEARNING']:
        df_rec_new.loc[index,"skills"]='Jr Scientist'
       
    if name in ['ENGINEER BIG','ENGINEER AWS AZURE','ENGINEER','SENIOR ENGINEER TABLEAU','ENGINEER BIGCLOUDERA','ENGINEER GCP BIGQUERY PYTHON','SENIOR   ENGINEER BIGAWS','ENGINEER AWS SQL','ENGINEER AWS CLOUD','CONSULTANT AWS SPARK REDSHIFT','SENIOR   CONSULTANT HADOOP','SENIOR   CONSULTANT AZURE','SENIOR    CLOUD','CONSULTANT CLOUD','CLOUD','LEAD    INTELLIGENCE SAS','ENGINEER CLOUD   LAKE','AWS SPARK PYTHON','ENGINEER AWS','SENIOR   ANALYTICS BIG','SENIOR   ANALYST AWS','LEAD  ANALYST BIG','SENIOR   ENGINEER AWS SPARK MACHINE LEARNING','ENGINEER SPARK SCALA','ENGINEER BIGAWS CLOUD','ENGINEER BIGSPARK','ENGINEER CLOUD LAKE','SENIOR   ENGINEER AZURE SQL AI PYTHON  DW','JUNIOR CONSULTANT BIG','SENIOR   ANALYST BIG','ENGINEER BIGAWS','JUNIOR ENGINEER SCALA SPARK AZURE','BIG','ENGINEER CLOUD','ANALYST BIG','SENIOR   CONSULTANT BIG','CLOUDERA HADOOP CLUSTER','ENGINEER AZURE']:
        df_rec_new.loc[index,"skills"]='Big data Eng'
       
    if name in ['SCIENTIST RESEARCH','RESEARCH',' RESEARCH LEAD','RESEARCH LEADER  ANALYTICS','RESEARCH SENIOR   ANALYST','RESEARCH SENIOR   ANALYTICS','RESEARCH   ANALYTICS','RESEARCH LEADER  ANALYTICS','RESEARCH LEAD','RESEARCH HEAD  ANALYTICS']:
        df_rec_new.loc[index,"skills"]='Research'
        
    if name in ['SENIOR   ENGINEER','LEAD  ENGINEER','SENIOR   ENGINEER  TABLEAU','SENIOR   ENGINEER    PHP','SENIOR   ENGINEER  SQL PYTHON  DW']:
        df_rec_new.loc[index,"skills"]='Big data Eng'
    print(index,name)
# Out:
# 0 SCIENTIST     BIGAZURE
# 1 SCIENTIST     BIGAZURE
# 2 SCIENTIST    ANALYTICS
# 3 SPECIALIST   ANALYTICS
# 4 SCIENTIST SENIOR
# 5 SCIENTIST     BIGAZURE
# 6 SCIENTIST
# 8 SCIENTIST
# 9 SCIENTIST
# 10 SCIENTIST SENIOR
# 11 ANALYTICS ENGINEER
# 13 SCIENTIST SENIOR
# 14 SCIENTIST
# 15 SCIENTIST RESEARCH
# 16 SCIENTIST RESEARCH
# 17 SCIENTIST SENIOR   CONSULTANT
# 18 SCIENTIST
# 19 ENGINEER
# 20 ENGINEER
# 21 SCIENTIST
# 22 SCIENTIST    ENGINEER
# 23 LEAD  ENGINEER
# 24 ENGINEER AZURE
# 25 SCIENTIST
# 26 SCIENTIST
# 27 RESEARCH   ANALYST
# 28 SCIENTIST    ANALYTICS  AI
# 29 SCIENTIST    ANALYTICS
# 30 ANALYST
# 31 SCIENTIST
# 32 RESEARCH SENIOR   ANALYTICS
# 33 SENIOR LEAD
# 35 SCIENTIST     AZURE
# 36 SCIENTIST
# 39 ANALYST BIG
# 40 SCIENTIST
# 41 ENGINEER
# 42 SCIENTIST SENIOR
# 43 SCIENTIST
# 44 SCIENTIST    ENGINEER  MACHINE LEARNING
# 45 ANALYST
# 46 ANALYST
# 47 ANALYST
# 48 SCIENTIST
# 49 JUNIOR ENGINEER SCALA SPARK AZURE
# 50 ENGINEER BIGAWS
# 51 SCIENTIST RESEARCH
# ...

# %%
df_groupby=df_rec_new.groupby(['skills','location','newclass1',"jobtype"])['label'].median()

# %%
#df_groupby.add_suffix('_Count')
df_groupby=df_groupby.reset_index()

# %%
df_t=df_rec_new[df_rec_new["label"].isnull()].merge(df_groupby,how='inner',on=["skills","location",'newclass1',"jobtype"],right_index=True,left_index=True)

# %%
for index,num in df_t["label_y"].iteritems():
    df_rec_new.loc[index,"label"]=num

# %%
df_groupby1=df_rec_new.groupby(['skills','location',"jobtype"])['label'].median()

# %%
df_groupby1=df_groupby1.reset_index()

# %%
df_groupby1
# Out:
#           skills                       location          jobtype  label
# 0    Jr Analysts                            ACT    Contract/Temp    0.5
# 1    Jr Analysts                            ACT        Full Time    NaN
# 2    Jr Analysts                       Adelaide    Contract/Temp    NaN
# 3    Jr Analysts                       Adelaide        Full Time    0.0
# 4    Jr Analysts         Bairnsdale & Gippsland    Contract/Temp    NaN
# 5    Jr Analysts                       Brisbane    Contract/Temp    0.0
# 6    Jr Analysts                       Brisbane        Full Time    0.0
# 7    Jr Analysts                         Darwin    Contract/Temp    NaN
# 8    Jr Analysts        Gosford & Central Coast    Contract/Temp    0.5
# 9    Jr Analysts                      Melbourne    Contract/Temp    0.0
# 10   Jr Analysts                      Melbourne        Full Time    0.0
# 11   Jr Analysts   Newcastle, Maitland & Hunter    Contract/Temp    NaN
# ...

# %%
df_t=df_rec_new[df_rec_new["label"].isnull()].merge(df_groupby1,how='inner',on=["skills","location","jobtype"],right_index=True,left_index=True)

# %%
for index,num in df_t["label_y"].iteritems():
    df_rec_new.loc[index,"label"]=num

# %%
df_groupby2=df_rec_new.groupby(['skills','location'])['label'].median()

# %%
df_groupby2=df_groupby2.reset_index()

# %%
df_t=df_rec_new[df_rec_new["label"].isnull()].merge(df_groupby2,how='inner',on=["skills","location"],left_index=True,right_index=True)

# %%
for index,num in df_t["label_y"].iteritems():
    df_rec_new.loc[index,"label"]=num

# %%
df_groupby3=df_rec_new.groupby(['skills'])['label'].median()

# %%
df_groupby3=df_groupby3.reset_index()

# %%
df_t=df_rec_new[df_rec_new["label"].isnull()].merge(df_groupby3,how='inner',on=["skills"],left_index=True,right_index=True)

# %%
for index,num in df_t["label_y"].iteritems():
    df_rec_new.loc[index,"label"]=num

# %%
df_rec_new.label.value_counts()
# Out:
# 0.0    239
# 1.0     49
# 2.0      4
# 3.0      2
# 0.5      2
# Name: label, dtype: int64

# %%
df_latest=df_rec_new[~df_rec_new["label"].isnull()]

# %%
ax=sns.barplot("skills","label",data=df_latest,ci=None)
loc, labels = plt.xticks()
ax.set(xlabel='Skills', ylabel='Salary')
ax.set_xticklabels(labels, rotation=45)
# Out:
# [Text(0, 0, 'Sr Scientist'),
#  Text(0, 0, 'Jr Scientist'),
#  Text(0, 0, 'Research'),
#  Text(0, 0, 'Big data Eng'),
#  Text(0, 0, ' Jr Analysts'),
#  Text(0, 0, 'Sr. Analyst')]

# %%
ax=sns.countplot("skills",data=df_latest,hue="jobtype")
loc, labels = plt.xticks()
ax.set(xlabel='Skills', ylabel='Count')
ax.set_xticklabels(labels, rotation=45)
# Out:
# [Text(0, 0, 'Sr Scientist'),
#  Text(0, 0, 'Jr Scientist'),
#  Text(0, 0, 'Research'),
#  Text(0, 0, 'Big data Eng'),
#  Text(0, 0, ' Jr Analysts'),
#  Text(0, 0, 'Sr. Analyst')]

# %%
ax=sns.countplot("newclass1",data=df_latest)
loc, labels = plt.xticks()
ax.set(xlabel='Skills', ylabel='Count')
ax.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0, 0, 'Information Technolog'),
#  Text(0, 0, 'Consulting & Strategy & Eng'),
#  Text(0, 0, 'Govt & Def & Edu & Train'),
#  Text(0, 0, 'Financial Services'),
#  Text(0, 0, 'Others'),
#  Text(0, 0, 'Human Resources & Recruitment & Admin & Office Support'),
#  Text(0, 0, 'Adv & Arts & Media & Mark & Comm & Sales'),
#  Text(0, 0, 'Man & Trans & Logistics & Cons')]

# %%
ax=sns.countplot("location",data=df_latest)
loc, labels = plt.xticks()
ax.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0, 0, 'Sydney'),
#  Text(0, 0, 'Newcastle, Maitland & Hunter'),
#  Text(0, 0, 'Melbourne'),
#  Text(0, 0, 'Adelaide'),
#  Text(0, 0, 'ACT'),
#  Text(0, 0, 'Brisbane'),
#  Text(0, 0, 'Horsham & Grampians'),
#  Text(0, 0, 'Bundaberg & Wide Bay Burnett'),
#  Text(0, 0, 'Perth'),
#  Text(0, 0, 'Blue Mountains & Central West'),
#  Text(0, 0, 'Ballarat & Central Highlands'),
#  Text(0, 0, 'Wollongong, Illawarra & South Coast'),
#  Text(0, 0, 'Gosford & Central Coast')]

# %%
df_latest.columns
# Out:
# Index(['Name', 'class1', 'class2', 'jobtype', 'location', 'salary', 'summary',
#        'title', 'sal', 'qual', 'new', 'skills3', 'skillspts3', 'title1',
#        'newclass1', 'label', 'skills'],
#       dtype='object')

# %%
y=df_latest["label"].values

# %%
y=np.trunc(y).astype(int)

# %%
np.unique(y,return_counts=True)
# Out:
# (array([0, 1, 2, 3]), array([241,  49,   4,   2], dtype=int64))

# %%
X=df_latest[["skills","location","jobtype","newclass1"]]

# %%
X["sk_lab"]=0
X["loc_lab"]=0
X["job_lab"]=0
# Out:
# C:\Users\Jyo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Jyo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Jyo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
for index, label in X["skills"].iteritems():
    if label == 'Sr Scientist':
        X.loc[index,"sk_lab"]=6
    elif label == 'Jr Scientist':
        X.loc[index,"sk_lab"]=5
    elif label == 'Big data Eng':
        X.loc[index,"sk_lab"]=5
    elif label =='Sr. Analyst':    
        X.loc[index,"sk_lab"]=4
    elif label ==' Jr Analysts':
        X.loc[index,"sk_lab"]=3
    elif label =='Research':
        X.loc[index,"sk_lab"]=2
# Out:
# C:\Users\Jyo\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for index, label in X["location"].iteritems():
    if label == 'Sydney':
        X.loc[index,"loc_lab"]=5
    elif label == 'Melbourne':
        X.loc[index,"loc_lab"]=4
    elif label == 'Brisbane':
        X.loc[index,"loc_lab"]=3
    elif label == 'Adelaide':
        X.loc[index,"loc_lab"]=2
    elif label == 'Perth':
        X.loc[index,"loc_lab"]=1
    else:
        X.loc[index,"loc_lab"]=0

# %%
for index, label in X["jobtype"].iteritems():
    if label == 'Contract/Temp':
        X.loc[index,"job_lab"]=1
    elif label == 'Full Time':
        X.loc[index,"job_lab"]=0

# %%
X.dtypes

# %%
X.drop("skills",axis=1,inplace=True)
# Out:
# C:\Users\Jyo\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
X.drop("jobtype",axis=1,inplace=True)

# %%
X.drop("location",axis=1,inplace=True)

# %%
Xdum=pd.get_dummies(X,columns=['newclass1'])

# %%
df_rec_new.to_csv("/Users/Jyo/Documents/GA/summary.csv",index=False)

# %%
from imblearn.over_sampling import SMOTE
X_resampled, y_resampled = SMOTE(k_neighbors=1).fit_resample(Xdum, y)

# %%
from sklearn.metrics import classification_report,roc_auc_score

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=2)
skf.get_n_splits(X_resampled, y_resampled)

 
for train_index, test_index in skf.split(X_resampled, y_resampled):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X_resampled[train_index], X_resampled[test_index]
    y_train, y_test = y_resampled[train_index], y_resampled[test_index]
# Out:
# TRAIN: [143 144 147 148 149 150 151 152 154 155 157 158 159 160 161 162 163 164
#  165 166 167 168 169 170 172 176 177 178 179 180 181 182 183 184 185 186
#  187 188 189 191 192 193 194 195 197 198 199 200 201 202 204 205 206 207
#  208 209 210 211 212 213 217 218 220 221 222 223 224 225 226 227 228 229
#  236 237 239 240 242 243 244 246 247 248 249 250 251 252 255 256 257 258
#  259 260 261 263 264 265 266 267 269 273 274 275 276 277 278 279 280 281
#  282 283 284 285 287 288 289 290 291 292 294 295 368 369 370 371 372 373
#  374 375 376 377 378 379 380 381 382 383 384 385 386 387 388 389 390 391
#  392 393 394 395 396 397 398 399 400 401 402 403 404 405 406 407 408 409
#  410 411 412 413 414 415 416 417 418 419 420 421 422 423 424 425 426 427
#  428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445
#  446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463
#  464 465 466 467 468 469 470 471 472 473 474 475 476 477 478 479 480 481
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score


#Lr=LogisticRegressionCV(Cs=1000, cv=5, penalty='l2', scoring='accuracy', solver='liblinear')
#Lr.fit(X_train,y_train)

#lr_ridge = LogisticRegressionCV(penalty='l2',multi_class='multinomial',Cs=1000, cv=10,n_jobs =-1)
#lr_ridge.fit(X_train, y_train)
clf=LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(X_train, y_train)
y_pred=clf.predict(X_test)
print(classification_report(y_test, y_pred, labels=[0, 1, 2,3]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.66      0.77        77
#            1       0.75      0.68      0.71        80
#            2       0.75      1.00      0.86        82
#            3       0.98      1.00      0.99        80
#
#    micro avg       0.84      0.84      0.84       319
#    macro avg       0.85      0.83      0.83       319
# weighted avg       0.85      0.84      0.83       319
# C:\Users\Jyo\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
clf.score(X_test,y_test)
# Out:
# 0.8369905956112853

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,roc_auc_score

neigh = KNeighborsClassifier(n_neighbors=10)
neigh.fit(X_train, y_train) 

y_pred=neigh.predict(X_test)

print(classification_report(y_test, y_pred, labels=[0, 1,2,3]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.57      0.64        77
#            1       0.79      0.53      0.63        80
#            2       0.75      1.00      0.86        82
#            3       0.83      1.00      0.91        80
#
#    micro avg       0.78      0.78      0.78       319
#    macro avg       0.77      0.77      0.76       319
# weighted avg       0.78      0.78      0.76       319

# %%
clf.score(X_test,y_test)
# Out:
# 0.8369905956112853

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(max_depth=2,n_estimators=100, random_state=0).fit(X_train,y_train)

# %%
print(clf.feature_importances_)

y_test=clf.predict(X_test)
print(classification_report(y_test, y_pred, labels=[0, 1, 2,3]))
# Out:
# [0.18796557 0.26823146 0.17910469 0.00266928 0.0103159  0.02132621
#  0.0891784  0.00033947 0.23979793 0.         0.00107108]
#               precision    recall  f1-score   support
#
#            0       0.44      0.73      0.55        37
#            1       0.70      0.37      0.48       100
#            2       0.69      0.88      0.77        85
#            3       0.91      0.90      0.90        97
#
#    micro avg       0.71      0.71      0.71       319
#    macro avg       0.68      0.72      0.68       319
# weighted avg       0.73      0.71      0.70       319

# %%
clf.score(X_test,y_test)
# Out:
# 1.0
